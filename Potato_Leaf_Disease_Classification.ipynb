# %% [markdown]
# Dataset URL : 'https://drive.google.com/drive/folders/1YDvvWptyTypE8OKJsfGrlTsyG7LDaCFm?usp=drive_link'

# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Loading the dataset**

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
          "/content/drive/MyDrive/Potato_Disease dataset",
          shuffle = True,
          image_size = (IMAGE_SIZE,IMAGE_SIZE),
          batch_size = BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset) # every batch is 32
# Out:
# 68

# %%
plt.figure(figsize = (10,10))
for image_batch, label_batch in dataset.take(1):
  for i in range(12):
     ax = plt.subplot(3,4,i+1)
     plt.imshow(image_batch[i].numpy().astype("uint8"))
     plt.axis("off")
     plt.title(class_names[label_batch[i]])

# %% [markdown]
# **Splitting the dataset**

# %% [markdown]
# 80% <- training
# 20% <- 10% validation,10% test

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 54.400000000000006

# %%
train_dataset = dataset.take(54)
len(train_dataset)
# Out:
# 54

# %%
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 14

# %%
val_size = 0.1
len(dataset)*val_size
# Out:
# 6.800000000000001

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 8

# %%
def get_dataset_partitions_tf(ds,train_split = 0.8, val_split = 0.1,test_split = 0.1,shuffle = True, shuffle_size = 10000):

  ds_size = len(ds)

  if shuffle:
    ds = ds.shuffle(shuffle_size, seed =12)

  train_size = int(train_split *ds_size)
  val_size = int(val_split * ds_size)

  train_ds = ds.take(train_size)

  val_ds = ds.skip(train_size).take(val_size)
  test_ds = ds.skip(train_size).skip(val_size)

  return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 54

# %%
len(val_ds)
# Out:
# 6

# %%
len(test_ds)
# Out:
# 8

# %% [markdown]
# **Data Preprocessing**

# %%
 train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
 val_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
 test_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255),
])

# %% [markdown]
# Data Augmentation

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
])

# %% [markdown]
# **Model Building**

# %% [markdown]
# Neural Network Architecture

# %%
input_shape = (BATCH_SIZE,IMAGE_SIZE,IMAGE_SIZE,CHANNELS)
n_classes = 3

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32, (3,3), activation = 'relu',input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu',input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu',input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu',input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu',input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, (3,3), activation = 'relu',input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64, activation = 'relu'),
    layers.Dense(n_classes,activation = 'softmax')

])
model.build(input_shape = input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2D  (32, 127, 127, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (32, 62, 62, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (32, 30, 30, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (32, 14, 14, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (32, 6, 6, 64)           0
#  2D)
#
#  conv2d_5 (Conv2D)           (32, 4, 4, 64)            36928
#
#  max_pooling2d_5 (MaxPooling  (32, 2, 2, 64)           0
#  2D)
#
#  flatten (Flatten)           (32, 256)                 0
#
#  dense (Dense)               (32, 64)                  16448
#
#  dense_1 (Dense)             (32, 3)                   195
#
# =================================================================
# Total params: 183,747
# Trainable params: 183,747
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compilation

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy']
)

# %%
history = model.fit(
    train_ds,
    epochs = EPOCHS,
    batch_size = BATCH_SIZE,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 173s 88ms/step - loss: 0.9071 - accuracy: 0.5058 - val_loss: 0.8238 - val_accuracy: 0.7135
# Epoch 2/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.6345 - accuracy: 0.7240 - val_loss: 0.4602 - val_accuracy: 0.7882
# Epoch 3/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.3903 - accuracy: 0.8247 - val_loss: 0.2800 - val_accuracy: 0.8935
# Epoch 4/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.3322 - accuracy: 0.8623 - val_loss: 0.4141 - val_accuracy: 0.8160
# Epoch 5/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.2710 - accuracy: 0.8877 - val_loss: 0.2623 - val_accuracy: 0.8912
# Epoch 6/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.2666 - accuracy: 0.8848 - val_loss: 0.2465 - val_accuracy: 0.8929
# Epoch 7/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.2117 - accuracy: 0.9097 - val_loss: 0.1576 - val_accuracy: 0.9381
# Epoch 8/50
# 54/54 [==============================] - 5s 84ms/step - loss: 0.1942 - accuracy: 0.9161 - val_loss: 0.1860 - val_accuracy: 0.9288
# Epoch 9/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.1854 - accuracy: 0.9271 - val_loss: 0.2972 - val_accuracy: 0.8802
# Epoch 10/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.1524 - accuracy: 0.9358 - val_loss: 0.1322 - val_accuracy: 0.9456
# Epoch 11/50
# 54/54 [==============================] - 4s 83ms/step - loss: 0.1521 - accuracy: 0.9352 - val_loss: 0.2464 - val_accuracy: 0.9045
# Epoch 12/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.1313 - accuracy: 0.9462 - val_loss: 0.2421 - val_accuracy: 0.9086
# Epoch 13/50
# 54/54 [==============================] - 5s 86ms/step - loss: 0.1542 - accuracy: 0.9456 - val_loss: 0.1575 - val_accuracy: 0.9358
# Epoch 14/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.1339 - accuracy: 0.9473 - val_loss: 0.1328 - val_accuracy: 0.9427
# Epoch 15/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.1264 - accuracy: 0.9502 - val_loss: 0.0958 - val_accuracy: 0.9618
# Epoch 16/50
# 54/54 [==============================] - 4s 83ms/step - loss: 0.1120 - accuracy: 0.9583 - val_loss: 0.0785 - val_accuracy: 0.9699
# Epoch 17/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.1205 - accuracy: 0.9560 - val_loss: 0.1490 - val_accuracy: 0.9450
# Epoch 18/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.0985 - accuracy: 0.9688 - val_loss: 0.3246 - val_accuracy: 0.8779
# Epoch 19/50
# 54/54 [==============================] - 4s 83ms/step - loss: 0.1062 - accuracy: 0.9606 - val_loss: 0.0738 - val_accuracy: 0.9664
# Epoch 20/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.1041 - accuracy: 0.9612 - val_loss: 0.1112 - val_accuracy: 0.9606
# Epoch 21/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.1140 - accuracy: 0.9578 - val_loss: 0.0982 - val_accuracy: 0.9583
# Epoch 22/50
# 54/54 [==============================] - 4s 83ms/step - loss: 0.1869 - accuracy: 0.9375 - val_loss: 0.2855 - val_accuracy: 0.8987
# Epoch 23/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0902 - accuracy: 0.9670 - val_loss: 0.0986 - val_accuracy: 0.9618
# Epoch 24/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0818 - accuracy: 0.9670 - val_loss: 0.1650 - val_accuracy: 0.9306
# Epoch 25/50
# 54/54 [==============================] - 4s 83ms/step - loss: 0.0786 - accuracy: 0.9711 - val_loss: 0.0763 - val_accuracy: 0.9711
# Epoch 26/50
# 54/54 [==============================] - 5s 85ms/step - loss: 0.0885 - accuracy: 0.9670 - val_loss: 0.0900 - val_accuracy: 0.9676
# Epoch 27/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0462 - accuracy: 0.9815 - val_loss: 0.0763 - val_accuracy: 0.9728
# Epoch 28/50
# 54/54 [==============================] - 5s 86ms/step - loss: 0.0582 - accuracy: 0.9809 - val_loss: 0.1607 - val_accuracy: 0.9329
# Epoch 29/50
# 54/54 [==============================] - 4s 83ms/step - loss: 0.0402 - accuracy: 0.9884 - val_loss: 0.2145 - val_accuracy: 0.9259
# Epoch 30/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.0498 - accuracy: 0.9815 - val_loss: 0.0368 - val_accuracy: 0.9873
# Epoch 31/50
# 54/54 [==============================] - 4s 84ms/step - loss: 0.1327 - accuracy: 0.9520 - val_loss: 0.1757 - val_accuracy: 0.9462
# Epoch 32/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.0446 - accuracy: 0.9855 - val_loss: 0.0783 - val_accuracy: 0.9728
# Epoch 33/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.0285 - accuracy: 0.9896 - val_loss: 0.2759 - val_accuracy: 0.9103
# Epoch 34/50
# 54/54 [==============================] - 4s 84ms/step - loss: 0.0360 - accuracy: 0.9884 - val_loss: 0.1559 - val_accuracy: 0.9450
# Epoch 35/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.0436 - accuracy: 0.9826 - val_loss: 0.1209 - val_accuracy: 0.9514
# Epoch 36/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0558 - accuracy: 0.9809 - val_loss: 0.0820 - val_accuracy: 0.9688
# Epoch 37/50
# 54/54 [==============================] - 5s 85ms/step - loss: 0.0284 - accuracy: 0.9902 - val_loss: 0.1476 - val_accuracy: 0.9444
# Epoch 38/50
# 54/54 [==============================] - 4s 82ms/step - loss: 0.0341 - accuracy: 0.9913 - val_loss: 0.3457 - val_accuracy: 0.8987
# Epoch 39/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0691 - accuracy: 0.9745 - val_loss: 0.1356 - val_accuracy: 0.9450
# Epoch 40/50
# 54/54 [==============================] - 5s 86ms/step - loss: 0.0451 - accuracy: 0.9826 - val_loss: 0.0174 - val_accuracy: 0.9954
# Epoch 41/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0509 - accuracy: 0.9832 - val_loss: 0.0871 - val_accuracy: 0.9635
# Epoch 42/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0333 - accuracy: 0.9902 - val_loss: 0.1383 - val_accuracy: 0.9491
# Epoch 43/50
# 54/54 [==============================] - 4s 83ms/step - loss: 0.0142 - accuracy: 0.9948 - val_loss: 0.1172 - val_accuracy: 0.9659
# Epoch 44/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0304 - accuracy: 0.9890 - val_loss: 0.1069 - val_accuracy: 0.9583
# Epoch 45/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0571 - accuracy: 0.9792 - val_loss: 0.0798 - val_accuracy: 0.9659
# Epoch 46/50
# 54/54 [==============================] - 4s 83ms/step - loss: 0.0389 - accuracy: 0.9855 - val_loss: 0.0540 - val_accuracy: 0.9763
# Epoch 47/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0215 - accuracy: 0.9931 - val_loss: 0.0917 - val_accuracy: 0.9641
# Epoch 48/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0304 - accuracy: 0.9902 - val_loss: 0.2620 - val_accuracy: 0.9126
# Epoch 49/50
# 54/54 [==============================] - 4s 83ms/step - loss: 0.0245 - accuracy: 0.9907 - val_loss: 0.0999 - val_accuracy: 0.9682
# Epoch 50/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0552 - accuracy: 0.9803 - val_loss: 0.0397 - val_accuracy: 0.9855

# %%
scores = model.evaluate(test_ds)
# Out:
# 54/54 [==============================] - 1s 23ms/step - loss: 0.0397 - accuracy: 0.9855

# %% [markdown]
# **Plotting**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize = (8,8))
plt.subplot(1,2,1)
plt.plot(range(EPOCHS),acc,label = 'Training Accuracy')
plt.plot(range(EPOCHS),val_acc,label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')


plt.subplot(1,2,2)
plt.plot(range(EPOCHS),loss,label = 'Training Loss')
plt.plot(range(EPOCHS),val_loss,label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Prediction**

# %%
def predict(model,img):
  img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
  img_array = tf.expand_dims(img_array,0)

  predictions = model.predict(img_array)

  predicted_class = class_names[np.argmax(predictions[0])]
  confidence = round(100 * (np.max(predictions[0])),2)
  return predicted_class, confidence

# %%
plt.figure(figsize = (15,15))
for images,labels in test_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3,3,i+1)
    plt.imshow(images[i].numpy().astype("uint8"))
    predicted_class , confidence = predict(model, images[i].numpy())
    actual_class = class_names[labels[i]]
    plt.title(f"Actual:{actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
    plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
